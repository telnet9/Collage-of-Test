# %%
import numpy as np
arr1=np.array([1,3,2,4,9])
arr2=np.ones(5)
arr3=np.zeros(3)
arr4=np.concatenate([arr1,arr2,arr3])
arr4
# Out:
# array([1., 3., 2., 4., 9., 1., 1., 1., 1., 1., 0., 0., 0.])

# %%
np.sort(arr1)
# Out:
# array([1, 2, 3, 4, 9])

# %%
print(arr1[2])
print(arr1[-3])
# Out:
# 2
# 2

# %%
arr1[1:4]
# Out:
# array([3, 2, 4])

# %%
arr1+arr2
# Out:
# array([ 2.,  4.,  3.,  5., 10.])

# %%
arr1*(-5)
# Out:
# array([ -5, -15, -10, -20, -45])

# %%
print(arr1.max())
print(arr1.min())
print(arr1.sum())
print(arr1.mean())
# Out:
# 9
# 1
# 19
# 3.8

# %%
arr1[(arr1<1)|(arr1>3)]
# Out:
# array([4, 9])
